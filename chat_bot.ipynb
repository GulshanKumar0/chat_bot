# %%
from tkinter import *
import tkinter as tk

# %%
data = {"intents": [
             {"tag": "mentor_intro",
              "patterns": ["hello", "hi", "good morning", "who are you", "introduce yourself", "what is your role"],
              "responses": [
                  "Gulshan, I am BPSC Teacher for Gulshan. We will focus on score-maximizing strategy with strict discipline.",
                  "Gulshan, I am your dedicated BPSC mentor. Ask a topic and I will explain it in exam-oriented language.",
                  "Gulshan, I am BPSC Teacher for Gulshan — personal mentor, test generator, and answer evaluator."
              ]
             },
             {"tag": "syllabus_guidance",
              "patterns": ["bpsc syllabus", "what to study for bpsc", "syllabus strategy", "prelims and mains syllabus"],
              "responses": [
                  "Gulshan, start with GS basics: History, Polity, Geography, Economy, Science, and Bihar-specific current affairs. Build notes topic-wise and revise weekly.",
                  "Gulshan, split preparation into Prelims MCQ practice + Mains answer writing. Daily: static subject + Bihar current affairs + PYQ analysis.",
                  "Gulshan, follow a 3-layer plan: concept clarity, PYQ-based practice, and timed revision tests."
              ]
             },
             {"tag": "test_generation",
              "patterns": ["make test", "generate quiz", "topic wise test", "full length test", "practice paper"],
              "responses": [
                  "Gulshan, I can generate a full-length BPSC test with marks distribution, timer, objective and descriptive sections. Tell me the topic.",
                  "Gulshan, choose: (1) 25-question topic quiz, (2) 50-question mixed GS test, or (3) Mains descriptive test.",
                  "Gulshan, I will prepare a BPSC-pattern test. Share subject, level, and available time."
              ]
             },
             {"tag": "answer_evaluation",
              "patterns": ["check my answer", "evaluate this answer", "give marks", "review my mains answer"],
              "responses": [
                  "Gulshan, submit your answer. I will give marks, strengths, mistakes, missing points, model answer, and improvement strategy.",
                  "Gulshan, write in intro-body-conclusion format. I will evaluate it like a BPSC examiner with topper-copy style feedback.",
                  "Gulshan, send your response and I will provide strict but constructive evaluation."
              ]
             },
             {"tag": "revision_task",
              "patterns": ["give revision task", "daily task", "micro test", "quick revision"],
              "responses": [
                  "Gulshan, today's task: revise one Bihar polity topic, solve 20 MCQs, and write one 150-word mains answer in 12 minutes.",
                  "Gulshan, micro-test: 10 MCQs + 1 short note. Target completion in 20 minutes with self-review.",
                  "Gulshan, revision drill: 30 minutes static GS + 15 minutes Bihar current affairs + 15 minutes PYQ analysis."
              ]
             },
             {"tag": "goodbye",
              "patterns": ["bye", "g2g", "see ya", "adios", "cya"],
              "responses": [
                  "Gulshan, session closed. Revise what we discussed and return with answers for evaluation.",
                  "Good work today, Gulshan. Stay consistent and practice timed answers.",
                  "Gulshan, end of session. Tomorrow we continue with a focused test and feedback cycle."
              ]
             }
]}

# %%
import json
import string
import random 
import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer 
import tensorflow as tf 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
lemmatizer = WordNetLemmatizer()
# Each list to create
words = []
classes = []
doc_X = []
doc_y = []
# Loop through all the intents
# tokenize each pattern and append tokens to words, the patterns and
# the associated tag to their associated list
for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens = nltk.word_tokenize(pattern)
        words.extend(tokens)
        doc_X.append(pattern)
        doc_y.append(intent["tag"])
    
    # add the tag to the classes if it's not there already 
    if intent["tag"] not in classes:
        classes.append(intent["tag"])
# lemmatize all the words in the vocab and convert them to lowercase
# if the words don't appear in punctuation
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
# sorting the vocab and classes in alphabetical order and taking the # set to ensure no duplicates occur
words = sorted(set(words))
classes = sorted(set(classes))

# %%
training = []
out_empty = [0] * len(classes)
# creating the bag of words model
for idx, doc in enumerate(doc_X):
    bow = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
    # mark the index of class that the current pattern is associated
    # to
    output_row = list(out_empty)
    output_row[classes.index(doc_y[idx])] = 1
    # add the one hot encoded BoW and associated classes to training 
    training.append([bow, output_row])
# shuffle the data and convert it to an array
random.shuffle(training)
training = np.array(training, dtype=object)
# split the features and target labels
train_X = np.array(list(training[:, 0]))
train_y = np.array(list(training[:, 1]))

# %%
input_shape = (len(train_X[0]),)
output_shape = len(train_y[0])
epochs = 200
# the deep learning model
model = Sequential()
model.add(Dense(128, input_shape=input_shape, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(output_shape, activation = "softmax"))
adam = tf.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=["accuracy"])
print(model.summary())
model.fit(x=train_X, y=train_y, epochs=200, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               5120
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 13,701
# Trainable params: 13,701
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 2s 2s/step - loss: 1.7479 - accuracy: 0.1053
# Epoch 2/200
# 1/1 [==============================] - 0s 18ms/step - loss: 1.5240 - accuracy: 0.4211
# Epoch 3/200
# 1/1 [==============================] - 0s 20ms/step - loss: 1.3602 - accuracy: 0.5789
# Epoch 4/200
# 1/1 [==============================] - 0s 20ms/step - loss: 1.2700 - accuracy: 0.5789
# Epoch 5/200
# 1/1 [==============================] - 0s 22ms/step - loss: 1.1927 - accuracy: 0.7368
# Epoch 6/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0811 - accuracy: 0.8947
# Epoch 7/200
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0252 - accuracy: 0.7368
# Epoch 8/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.9023 - accuracy: 0.8421
# Epoch 9/200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.8529 - accuracy: 0.7895
# Epoch 10/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5129 - accuracy: 0.9474
# Epoch 11/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5208 - accuracy: 0.8947
# Epoch 12/200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3500 - accuracy: 1.0000
# Epoch 13/200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3431 - accuracy: 0.9474
# Epoch 14/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.3069 - accuracy: 0.8947
# Epoch 15/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2704 - accuracy: 0.8947
# Epoch 16/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2251 - accuracy: 0.8947
# Epoch 17/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1368 - accuracy: 1.0000
# Epoch 18/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2256 - accuracy: 0.8947
# Epoch 19/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1201 - accuracy: 0.9474
# Epoch 20/200
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2448 - accuracy: 0.8947
# Epoch 21/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1534 - accuracy: 0.9474
# Epoch 22/200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1852 - accuracy: 0.9474
# Epoch 23/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0471 - accuracy: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0522 - accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1006 - accuracy: 0.9474
# Epoch 26/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0350 - accuracy: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0545 - accuracy: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1134 - accuracy: 0.9474
# Epoch 29/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0603 - accuracy: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0503 - accuracy: 0.9474
# Epoch 32/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0762 - accuracy: 0.9474
# Epoch 33/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0494 - accuracy: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0719 - accuracy: 0.9474
# Epoch 36/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0333 - accuracy: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0507 - accuracy: 0.9474
# Epoch 50/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 13ms/step - loss: 4.9684e-04 - accuracy: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 20ms/step - loss: 7.7807e-04 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 13ms/step - loss: 6.6660e-04 - accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 14ms/step - loss: 3.8332e-04 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 13ms/step - loss: 7.1153e-04 - accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 6ms/step - loss: 9.9173e-05 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 13ms/step - loss: 2.3047e-04 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 13ms/step - loss: 7.3271e-04 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 18ms/step - loss: 4.6904e-04 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 16ms/step - loss: 8.1813e-04 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 21ms/step - loss: 9.9389e-05 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 18ms/step - loss: 4.4588e-04 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 24ms/step - loss: 2.1658e-04 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 16ms/step - loss: 3.0128e-04 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 22ms/step - loss: 4.9843e-05 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 21ms/step - loss: 1.3296e-04 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1944e-04 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 18ms/step - loss: 5.8894e-04 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 20ms/step - loss: 9.6023e-04 - accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 17ms/step - loss: 4.8391e-04 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 16ms/step - loss: 1.5506e-04 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 17ms/step - loss: 2.2244e-04 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 25ms/step - loss: 9.7902e-04 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 22ms/step - loss: 2.7837e-04 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 18ms/step - loss: 4.4363e-04 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7372e-04 - accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 13ms/step - loss: 3.0418e-04 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 8ms/step - loss: 7.2359e-05 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.6739e-05 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.7875e-04 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.7712e-05 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 16ms/step - loss: 8.8630e-04 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 13ms/step - loss: 8.1321e-05 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 18ms/step - loss: 2.7060e-04 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 9ms/step - loss: 4.4736e-04 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 19ms/step - loss: 3.7163e-04 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 15ms/step - loss: 4.7151e-05 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 12ms/step - loss: 2.0856e-04 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 23ms/step - loss: 3.2628e-04 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 14ms/step - loss: 9.7578e-05 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 30ms/step - loss: 2.7496e-05 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 18ms/step - loss: 1.4122e-05 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 13ms/step - loss: 2.3101e-04 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1151 - accuracy: 0.9474
# Epoch 134/200
# 1/1 [==============================] - 0s 16ms/step - loss: 6.2215e-04 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 12ms/step - loss: 9.8438e-05 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 19ms/step - loss: 1.9974e-04 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 15ms/step - loss: 1.4177e-04 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 11ms/step - loss: 9.8999e-04 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 16ms/step - loss: 7.3851e-05 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 17ms/step - loss: 7.6185e-04 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 22ms/step - loss: 9.4094e-04 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 18ms/step - loss: 1.5998e-04 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 19ms/step - loss: 3.2842e-04 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 13ms/step - loss: 6.2784e-04 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1527e-04 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 12ms/step - loss: 2.7666e-04 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 28ms/step - loss: 3.8345e-04 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 16ms/step - loss: 6.5810e-04 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 15ms/step - loss: 7.4784e-04 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 21ms/step - loss: 1.4208e-04 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0296 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.8862e-04 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 17ms/step - loss: 5.9002e-05 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.0950e-04 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.0261e-04 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.7141e-04 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 15ms/step - loss: 2.6365e-04 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 18ms/step - loss: 1.9319e-04 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 12ms/step - loss: 2.7825e-04 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 15ms/step - loss: 8.2428e-04 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 19ms/step - loss: 8.4688e-04 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 16ms/step - loss: 4.2484e-04 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 16ms/step - loss: 4.5710e-04 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 12ms/step - loss: 8.0359e-04 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 11ms/step - loss: 5.9265e-04 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 20ms/step - loss: 2.8095e-04 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 16ms/step - loss: 4.9440e-04 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 12ms/step - loss: 4.5880e-04 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 18ms/step - loss: 2.8462e-04 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 19ms/step - loss: 1.8749e-04 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 19ms/step - loss: 1.2477e-04 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 28ms/step - loss: 1.7311e-04 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 18ms/step - loss: 1.2742e-04 - accuracy: 1.0000

# %%
def clean_text(text): 
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words(text, vocab): 
  tokens = clean_text(text)
  bow = [0] * len(vocab)
  for w in tokens: 
    for idx, word in enumerate(vocab):
      if word == w: 
        bow[idx] = 1
  return np.array(bow)

def pred_class(text, vocab, labels): 
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0]
  thresh = 0.2
  y_pred = [[idx, res] for idx, res in enumerate(result) if res > thresh]

  y_pred.sort(key=lambda x: x[1], reverse=True)
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]])
  return return_list

def get_response(intents_list, intents_json): 
  if not intents_list:
    return "Gulshan, ask a specific BPSC topic, test request, or answer-evaluation prompt so I can guide you better."

  tag = intents_list[0]
  list_of_intents = intents_json["intents"]
  for i in list_of_intents: 
    if i["tag"] == tag:
      return random.choice(i["responses"])

  return "Gulshan, I did not match that clearly. Please rephrase with a BPSC-focused request."

# %%
while True:
    message = input("")
    intents = pred_class(message, words, classes)
    result = get_response(intents, data)
    print(result)
# Out:
# Hello
# I'm Kippi
